# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

# %%
fileArmi = pd.read_csv('Total-arms-sales-SIPRI-Top-100-2002-2020.csv',sep=';')
fileArmi
# Out:
#                           Type   2002   2003   2004   2005   2006   2007  \
# 0         current U$ (billion)  201.0  239.0  277.0  293.0  316.0  349.0
# 1                       change    NaN   18.9   16.0    5.7    7.7   10.6
# 2                          NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 3  constant 2020 US$ (billion)  297.0  324.0  356.0  365.0  382.0  399.0
# 4                       change    NaN    9.3    9.7    2.7    4.6    4.4
#
#     2008   2009   2010  ...   2012   2013   2014   2015   2016   2017   2018  \
# 0  392.0  405.0  420.0  ...  405.0  406.0  398.0  428.0  441.0  458.0  484.0
# 1   12.2    3.3    3.9  ...   -3.5    0.3   -2.1    7.7    2.9    3.8    5.9
# 2    NaN    NaN    NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 3  427.0  456.0  463.0  ...  419.0  410.0  397.0  454.0  471.0  476.0  491.0
# 4    7.1    6.8    1.5  ...   -4.4   -2.2   -3.2   14.3    3.9    1.0    3.1
#
#     2019   2020  2002-2020
# 0  518.0  531.0        NaN
# ...

# %%
fileSpeseArmi = pd.read_csv('SpesePerArmi.csv',sep=';')
fileSpeseArmi
# Out:
#                                Region    2000    2001    2002    2003    2004  \
# 0                               World  1123,5  1148,3  1224,1  1313,7  1399,9
# 1                              Africa    17,4    17,6    20,1    18,2    21,1
# 2                        North Africa     4,8     5,8     5,9     6,1     6,6
# 3                  sub-Saharan Africa    12,6    11,8    14,3    12,1    14,5
# 4                            Americas   525,0   532,0   591,4   664,7   721,8
# 5   Central America and the Caribbean     4,3     4,5     4,2     4,2     3,9
# 6                       North America   494,3   498,5   558,2   633,7   689,9
# 7                       South America    26,5    29,1    29,0    26,8    28,0
# 8                      Asia & Oceania   196,7   208,0   217,8   226,9   240,5
# 9                             Oceania    16,0    16,5    17,1    17,4    18,0
# 10                         South Asia    38,7    39,9    39,9    40,9    46,6
# ...

# %%
fileSpeseArmiFormattato = pd.read_csv('SpesePerArmi copia.csv',sep=';')
fileSpeseArmiFormattato
# Out:
#            Region   2000   2001   2002   2003   2004   2005   2006   2007  \
# 0          Africa   17.4   17.6   20.1   18.2   21.1   21.4   24.6   26.0
# 1         America  525.0  532.0  591.4  664.7  721.8  755.7  767.9  791.5
# 2  Asia & Oceania  196.7  208.0  217.8  226.9  240.5  252.5  266.8  282.8
# 3         Oceania   16.0   16.5   17.1   17.4   18.0   18.5   19.6   20.7
# 4          Europa  287.6  290.3  297.5  304.0  307.9  305.6  316.4  325.0
# 5   Medio Oriente   96.6  100.2   97.2   99.9  108.5  119.1  129.1  138.9
#
#     2008  ...   2013   2014   2015   2016   2017   2018   2019   2020   2021  \
# 0   30.4  ...   38.4   40.0   38.5   37.1   36.5   34.7   35.8   36.4   36.9
# 1  849.4  ...  821.1  775.6  761.3  758.1  756.7  778.8  818.6  856.2  845.8
# 2  300.0  ...  390.5  411.1  433.8  456.2  476.8  494.9  519.4  534.2  553.1
# 3   21.3  ...   21.9   23.6   25.8   28.2   28.3   28.0   29.1   30.5   31.6
# ...

# %%
plt.figure(figsize=(14, 7))

#plt.grid()
#sns.set_style("whitegrid")

color = sns.color_palette("deep")
bar1 = sns.barplot(x="Region",  y="2021", data=fileSpeseArmiFormattato, color=color[3])
bar2 = sns.barplot(x="Region", y='2000', data=fileSpeseArmiFormattato, color=color[2])

tot = mpatches.Patch(color=color[3], label='2021')
wheatA = mpatches.Patch(color=color[2], label='2000')

plt.title("Soldi Spesi per le Armi",fontsize=20)
plt.xticks(fontsize=14, rotation=45)
plt.yticks(fontsize=12, rotation=45)
plt.xlabel('')
plt.ylabel('')
plt.legend(handles=[tot, wheatA],fontsize=15)

plt.show()

# %%
fig, ax= plt.subplots(figsize=(14,7))

# plt.grid()
colors = sns.color_palette('deep')

plt.title('Spese per Armi 2000-2021',fontsize=20)
plt.xticks(fontsize=14,rotation=45)
plt.xticks(fontsize=12,rotation=45)

for i in range(len(fileSpeseArmiFormattato)):
    val = pd.DataFrame({
      'x_axis': fileSpeseArmiFormattato.keys()[1:-1],
      'y_axis': fileSpeseArmiFormattato.loc[i][1:-1].values
    })
    plt.plot('x_axis', 'y_axis', data=val, linestyle='-',linewidth=2,label=fileSpeseArmiFormattato.loc[i]['Region'])
    
ax.legend()

# %%
fileTop100_2020 = pd.read_csv('Top100_2020.csv',sep=';')
fileTop100_2020
# Out:
#     Rank (2020) *Note (b) Rank (2019)               Company (c)  Notes (2020)  \
# 0                       1           1      Lockheed Martin Corp.          NaN
# 1                       2           -      Raytheon Technologies            f
# 2                       3           2                     Boeing          NaN
# 3                       4           3     Northrop Grumman Corp.          NaN
# 4                       5           5     General Dynamics Corp.          NaN
# ..                    ...         ...                        ...          ...
# 102                    96          96                     ViaSat          NaN
# 103                    97         103  Mitsubishi Electric Corp.            g
# 104                    98          98                        CAE          NaN
# 105                    99         115            Mercury Systems          NaN
# 106                   100         110          Kongsberg Gruppen          NaN
#
# ...

# %%
plt.figure(figsize=(20, 10))

#plt.grid()

country = [
"Stati Uniti",
"Regno Unito",
"Cina",
"Reti Transeuropee",
"Italia",
"Francia",
"Russia",
"Emirati Arabi",
"Giappone",
"Germania",
"Israele",
"Svezia",
"India",
"Sud Korea",
"Tuchia",
"Singapore",
"Poloni",
"Ucraina",
"Spagna",
"Canada",
"Norvegia"
]
tot = []

for el in fileTop100_2020['Country'].unique():
    app = len(fileTop100_2020[fileTop100_2020.Country == el])
    tot.append(app)

color = sns.color_palette("deep")

df = pd.DataFrame({
    'Country' : country,
    'Tot' : tot
})

order_df = df.sort_values(by=['Tot'])

plt.barh(y='Country',  width='Tot' , data = order_df,color=color[9])

plt.title('Top 100 Aziende Produttrici di Armi',fontsize=20)
plt.xticks(fontsize=12, rotation=45)
plt.yticks(fontsize=14, rotation=45)

plt.show()

# %%
fileNucleari = pd.read_csv('Nucleari.csv',sep=';')
fileNucleari
# Out:
#     Year  United States  Russia  United Kingdom  France  China  Israel  India  \
# 0   1945              2       0               0       0      0       0      0
# 1   1946              9       0               0       0      0       0      0
# 2   1947             13       0               0       0      0       0      0
# 3   1948             50       0               0       0      0       0      0
# 4   1949            170       1               0       0      0       0      0
# ..   ...            ...     ...             ...     ...    ...     ...    ...
# 73  2018           4000    4350             215     300    280      80    135
# 74  2019           3800    4490             215     300    290      85    140
# 75  2020           3800    4310             195     290    320      90    150
# 76  2021           5550    6225             225     290    350      90    156
# 77  2022           3708    4477             180     290    350      90    160
#
#     Pakistan  North Korea
# ...

# %%
country = []
count = []
for k in fileNucleari.keys()[1:]:
    for el in fileNucleari[k].values:
        country.append(k)
        count.append(el)
fileNucleariFormattato = pd.DataFrame({
    'Country':country,
    'Count':count
})
fileNucleariFormattato
# Out:
#            Country  Count
# 0    United States      2
# 1    United States      9
# 2    United States     13
# 3    United States     50
# 4    United States    170
# ..             ...    ...
# 697    North Korea     10
# 698    North Korea     15
# 699    North Korea     35
# 700    North Korea     40
# 701    North Korea     20
#
# [702 rows x 2 columns]

# %%
fig, ax = plt.subplots(figsize = (14,7))
plt.title('Quantità di Armi nucleari (1945-2020)',fontsize=20)
x = fileNucleariFormattato['Count']
plt.xticks(fontsize=12,rotation=45)
plt.yticks(fontsize=14,rotation=45)

labels = [
    'Stati Uniti',
    'Russia',
    'Regno Unito',
    'Francia',
    'Cina',
    'Israele',
    'India',
    'Pakistan',
    'Corea del Nord'
]

sns.stripplot(y="Country", x="Count", data=fileNucleariFormattato,palette='deep',label=labels)
# Out:
# <AxesSubplot:title={'center':'Quantità di Armi nucleari (1945-2020)'}, xlabel='Count', ylabel='Country'>

# %%
fileArmiCategoria = pd.read_csv('Weapon category.csv')
fileArmiCategoria
# Out:
#          Equipment_Type    1950    1951     1952     1953     1954     1955  \
# 0              Aircraft  5333.0  6714.0  11618.0  15965.0  13193.0  12509.0
# 1   Air defence systems     NaN     NaN     42.0     42.0     56.0    197.0
# 2     Armoured vehicles  1045.0  1010.0   2491.0   4138.0   2917.0   2120.0
# 3             Artillery   316.0   535.0    631.0    719.0    572.0    808.0
# 4               Engines   468.0   773.0    818.0   1141.0   1003.0   1096.0
# 5              Missiles     NaN     NaN      NaN      NaN      NaN     57.0
# 6         Naval weapons     1.0    12.0      NaN    133.0     40.0    129.0
# 7                 Other     NaN     NaN      NaN      NaN      NaN      NaN
# 8            Satellites     NaN     NaN      NaN      NaN      NaN      NaN
# 9               Sensors    25.0     4.0     74.0    242.0    393.0    410.0
# 10                Ships   952.0  2450.0    859.0   1647.0   2197.0   2821.0
#
# ...

# %%
typeW = []
number = []
for i in range(len(fileArmiCategoria['Equipment_Type'])):
    for v in range(len(fileArmiCategoria[fileArmiCategoria.Equipment_Type == fileArmiCategoria['Equipment_Type'][i]].values[0][1:])):
        typeW.append(fileArmiCategoria['Equipment_Type'][i])
        number.append(fileArmiCategoria[fileArmiCategoria.Equipment_Type == fileArmiCategoria['Equipment_Type'][i]].values[0][v+1])

        
fileArmiCategoriaFormattato = pd.DataFrame({
    'Type':typeW,
    'Number':number
})
fileArmiCategoriaFormattato
# Out:
#          Type   Number
# 0    Aircraft   5333.0
# 1    Aircraft   6714.0
# 2    Aircraft  11618.0
# 3    Aircraft  15965.0
# 4    Aircraft  13193.0
# ..        ...      ...
# 776     Ships   4430.0
# 777     Ships   5119.0
# 778     Ships   3405.0
# 779     Ships   2027.0
# 780     Ships   2969.0
#
# [781 rows x 2 columns]

# %%
fig, ax = plt.subplots(figsize = (14,7))
sns.set_style('whitegrid')
#plt.grid()
plt.title('Distribuzione Tipi di Armi Vendute (1950-2020)',fontsize=20)
plt.xticks(fontsize=14,rotation=45)
plt.yticks(fontsize=12,rotation=45)
plt.xlabel('')
plt.ylabel('')
sns.boxplot( x=fileArmiCategoriaFormattato["Number"], y=fileArmiCategoriaFormattato["Type"],notch=True ,palette='deep')
plt.show()

# %%
fig, ax = plt.subplots(figsize = (14,7))
plt.title('Distribuzione Tipi di Armi Vendute (1950-2020)',fontsize=20)
plt.xticks(fontsize=14,rotation=45)
plt.yticks(fontsize=12,rotation=45)
plt.xlabel('')
plt.ylabel('')
sns.violinplot( x=fileArmiCategoriaFormattato["Number"], y=fileArmiCategoriaFormattato["Type"],palette='deep')
plt.show()

# %%
fileImportExport = pd.read_csv('SIPRI ARMS TRANSFER DATA.csv')
fileImportExport
# Out:
#                 Supplier  1950   1951   1952   1953   1954   1955   1956  \
# 0                Albania   NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1                Algeria   NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2                 Angola   NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 3              Argentina   NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 4                Armenia   NaN    NaN    NaN    NaN    NaN    NaN    NaN
# ..                   ...   ...    ...    ...    ...    ...    ...    ...
# 388  Yemen Arab Republic   NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 389           Yugoslavia   NaN  182.0  490.0  525.0  534.0  334.0  352.0
# 390               Zambia   NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 391     ZAPU (Zimbabwe)*   NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 392             Zimbabwe   1.0   11.0    2.0    8.0   36.0   27.0    8.0
#
#       1957   1958  ...  2012  2013  2014  2015  2016  2017  2018  2019  2020  \
# ...

# %%
fileImportExport[fileImportExport.Supplier == 'China']
# Out:
#     Supplier    1950    1951    1952    1953    1954    1955    1956    1957  \
# 21     China     NaN     NaN     NaN     NaN     3.0     NaN    39.0    30.0
# 173    China  2572.0  2197.0  3430.0  3144.0  3500.0  1730.0  2255.0  2126.0
#
#        1958  ...    2012    2013    2014    2015    2016    2017    2018  \
# 21    463.0  ...  1526.0  2067.0  1212.0  1780.0  2410.0  1438.0  1169.0
# 173  2778.0  ...  1571.0  1289.0  1077.0  1262.0  1139.0  1338.0  1962.0
#
#        2019   2020  Tranfer_Type
# 21   1472.0  760.0        Export
# 173  1347.0  811.0        Import
#
# [2 rows x 73 columns]

# %%
cina = fileImportExport[fileImportExport.Supplier == 'China']
cinaImport = cina[cina.Tranfer_Type == 'Import']
cinaExport = cina[cina.Tranfer_Type == 'Export']

# %%
fileImportExport = fileImportExport.fillna(0)

# %%
sum(fileImportExport[fileImportExport.Tranfer_Type == 'Export']['2020'].values)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/5n/c_5hmjkx76g_wz47_ksbp6jc0000gn/T/ipykernel_1125/2953071738.py in <module>
# ----> 1 sum(fileImportExport[fileImportExport.Tranfer_Type == 'Export']['2020'].values)
#
# TypeError: 'numpy.float64' object is not callable

# %%
cina = fileImportExport[fileImportExport.Supplier == 'China']
russia = fileImportExport[fileImportExport.Supplier == 'Russia']
usa = fileImportExport[fileImportExport.Supplier == 'United States']
francia = fileImportExport[fileImportExport.Supplier == 'France']
germania = fileImportExport[fileImportExport.Supplier == 'Germany']

# %%
cinaExport = cina[cina.Tranfer_Type == 'Export']
russiaExport = russia[russia.Tranfer_Type == 'Export']
usaExport = usa[usa.Tranfer_Type == 'Export']
franciaExport = francia[francia.Tranfer_Type == 'Export']
germaniaExport = germania[germania.Tranfer_Type == 'Export']

# %%
tot = cinaExport['2020'].values[0] + russiaExport['2020'].values[0] + usaExport['2020'].values[0] + franciaExport['2020'].values[0] + germaniaExport['2020'].values[0]
tot
# Out:
# 16562.0

# %%
fig, ax = plt.subplots(figsize = (14,7))
names = ['Cina', 'Russia', 'USA', 'Francia','Germania','Altro']
size = [
    cinaExport['2020'].values[0],
    russiaExport['2020'].values[0],
    usaExport['2020'].values[0],
    franciaExport['2020'].values[0],
    germaniaExport['2020'].values[0],
    22800 - tot
]
 
my_circle = plt.Circle( (0,0), 0.7, color='white')

colors = sns.color_palette('deep')
plt.pie(size, labels=names, wedgeprops = {'edgecolor' : 'white' },colors=colors)
p = plt.gcf()
p.gca().add_artist(my_circle)
plt.show()
