# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import numpy as np
import seaborn as sns
from math import log
from math import pi

# %%
fileFastFood = pd.read_csv('FastFood.csv')
fileFastFood
# Out:
#      Unnamed: 0 restaurant                                       item  \
# 0             1  Mcdonalds           Artisan Grilled Chicken Sandwich
# 1             2  Mcdonalds             Single Bacon Smokehouse Burger
# 2             3  Mcdonalds             Double Bacon Smokehouse Burger
# 3             4  Mcdonalds  Grilled Bacon Smokehouse Chicken Sandwich
# 4             5  Mcdonalds   Crispy Bacon Smokehouse Chicken Sandwich
# ..          ...        ...                                        ...
# 510         511  Taco Bell             Spicy Triple Double Crunchwrap
# 511         512  Taco Bell                Express Taco Salad w/ Chips
# 512         513  Taco Bell                     Fiesta Taco Salad-Beef
# 513         514  Taco Bell                  Fiesta Taco Salad-Chicken
# 514         515  Taco Bell                    Fiesta Taco Salad-Steak
#
#      calories  cal_fat  total_fat  sat_fat  trans_fat  cholesterol  sodium  \
# ...

# %%
fig, ax = plt.subplots(figsize = (14,7))
# sns.set_style('whitegrid')
plt.title('Distribuzione Grassi nei Cibi nei Fast Food',fontsize=20)
plt.xticks(fontsize=14,rotation=45)
plt.yticks(fontsize=12,rotation=45)
plt.xlabel('')
plt.ylabel('')
sns.boxplot( x=fileFastFood["total_fat"], y=fileFastFood["restaurant"],notch=True ,palette='deep')
plt.show()

# %%
fig, ax = plt.subplots(figsize = (14,7))
plt.title('Distribuzione Grassi nei Cibi nei Fast Food',fontsize=20)
plt.xticks(fontsize=14,rotation=45)
plt.yticks(fontsize=12,rotation=45)
plt.xlabel('')
plt.ylabel('')
sns.violinplot( x=fileFastFood["total_fat"], y=fileFastFood["restaurant"],palette='deep')
plt.show()

# %%
fileCostoCibo = pd.read_csv('CostoCiboRapporto.csv',sep=';')
fileCostoCibo
# Out:
#                                  Country     USD
# 0                            South Sudan  392.82
# 1                                Burundi   90.73
# 2                                 Malawi   74.00
# 3                                  Haiti   73.76
# 4                                  Sudan   60.52
# 5                                   Mali   48.62
# 6                             Mozambique   46.19
# 7                               Zimbabwe   46.17
# 8   The Democratic Republic of the Congo   43.93
# 9                                  Congo   32.12
# 10                          Burkina Faso   29.47
# 11                               Lesotho   27.19
# 12                            Tajikistan   26.95
# 13                                Gambia   26.26
# 14                                Rwanda   20.92
# 15                              Tanzania   19.91
# 16                                Uganda   19.63
# 17                                 Benin   18.70
# ...

# %%
# https://cdn.wfp.org/2020/plate-of-food/

fig, ax = plt.subplots(figsize = (20,15))

colors = sns.color_palette('Spectral',len(fileCostoCibo))

plt.title('Costo del Cibo (€) (per stipendio medio)',fontsize=25)
plt.xticks(fontsize=14,rotation=45)
plt.yticks(fontsize=16,rotation=45)

eur = []

for x in fileCostoCibo.USD.values:
    eur.append(x*1.04)

plt.barh(y=fileCostoCibo.Country, width=eur,color=colors)
# Out:
# <BarContainer object of 37 artists>

# %%
# https://startupitalia.eu/67000-20220511-il-mondo-della-food-innovation-si-da-appuntamento-a-todi?infinite
fileSpeseCibo = pd.read_csv('SpeseCibo.csv',sep=';')
fileSpeseCibo

# %%
# https://startupitalia.eu/67000-20220511-il-mondo-della-food-innovation-si-da-appuntamento-a-todi?infinite

fig, ax = plt.subplots(figsize = (20,15))

colors = sns.color_palette('deep')

plt.title('Percentuale Spese nel Cibo per Stipendio Medio',fontsize=20)
plt.xticks(fontsize=12,rotation=45)
plt.yticks(fontsize=14,rotation=45)

plt.barh(y=fileSpeseCibo.Country, width=fileSpeseCibo.Perc,color=colors[4])
# Out:
# <BarContainer object of 22 artists>

# %%
# https://www.statista.com/statistics/319095/frequency-of-eating-fast-food-us/
fileFreqFastFood = pd.read_csv('FrequenzaFastFood.csv',sep=';')
fileFreqFastFood
# Out:
#                      Frequency  Perc
# 0               Tutti i giorni   5.2
# 1  Alcune volte alla settimana  19.0
# 2        Una volta a settimana  21.0
# 3         Alcune volte al mese  22.8
# 4            Una volta al mese  12.2
# 5                    Raramente  17.6
# 6                          Mai   2.2

# %%
# https://www.statista.com/statistics/319095/frequency-of-eating-fast-food-us/

fig, ax= plt.subplots(figsize=(7,7))
plt.subplots_adjust(bottom=0.3)
plt.title('Frequenza Fast Food AGGIUNGERE %',fontsize=20)

labels = fileFreqFastFood['Frequency'].values

colors = sns.color_palette('deep')
plt.pie(fileFreqFastFood['Perc'].values, colors = colors)

patch1 = mpatches.Patch(color=colors[0], label=labels[0])
patch2 = mpatches.Patch(color=colors[1], label=labels[1])
patch3 = mpatches.Patch(color=colors[2], label=labels[2])
patch4 = mpatches.Patch(color=colors[3], label=labels[3])

handles = []

index = 0
for el in labels:
    handles.append(mpatches.Patch(color=colors[index], label=labels[index]))
    index += 1

ax.legend(handles=handles,loc="center", bbox_to_anchor=(1.25,0.80))
plt.show()

# %%
# https://it.ripleybelieves.com/world-s-fattest-countries-2105
# https://thebarbecuelab.com/fast-food/

# %%
fig, ax = plt.subplots(figsize = (14,7))
plt.title('Calorie nei Cibi nei Fast Food',fontsize=20)
plt.xticks(fontsize=14,rotation=45)
plt.yticks(fontsize=12,rotation=45)

sns.stripplot(x="restaurant", y="calories", data=fileFastFood,palette='deep')

fileFastFood[fileFastFood.calories>2000]
# Out:
#     Unnamed: 0 restaurant                                        item  \
# 39          40  Mcdonalds  20 piece Buttermilk Crispy Chicken Tenders
#
#     calories  cal_fat  total_fat  sat_fat  trans_fat  cholesterol  sodium  \
# 39      2430     1270        141     24.0        2.0          475    6080
#
#     total_carb  fiber  sugar  protein  vit_a  vit_c  calcium  salad
# 39         103    2.0      3    186.0    0.0    2.0      8.0  Other

# %%
fileConsumo = pd.read_csv('food_consumption.csv')
fileConsumo
# Out:
#          country             food_category  consumption  co2_emmission
# 0      Argentina                      Pork        10.51          37.20
# 1      Argentina                   Poultry        38.66          41.53
# 2      Argentina                      Beef        55.48        1712.00
# 3      Argentina               Lamb & Goat         1.56          54.63
# 4      Argentina                      Fish         4.36           6.96
# ...          ...                       ...          ...            ...
# 1425  Bangladesh        Milk - inc. cheese        21.91          31.21
# 1426  Bangladesh  Wheat and Wheat Products        17.47           3.33
# 1427  Bangladesh                      Rice       171.73         219.76
# 1428  Bangladesh                  Soybeans         0.61           0.27
# 1429  Bangladesh   Nuts inc. Peanut Butter         0.72           1.27
#
# [1430 rows x 4 columns]

# %%
fileConsumo.food_category.unique()
# Out:
# array(['Pork', 'Poultry', 'Beef', 'Lamb & Goat', 'Fish', 'Eggs',
#        'Milk - inc. cheese', 'Wheat and Wheat Products', 'Rice',
#        'Soybeans', 'Nuts inc. Peanut Butter'], dtype=object)

# %%
fig, ax = plt.subplots(figsize = (14,7))
plt.title('Tipi di cibo consumati nel Mondo',fontsize=20)
plt.xticks(fontsize=12,rotation=45)
plt.yticks(fontsize=14,rotation=45)

sns.stripplot(y="food_category", x="consumption", data=fileConsumo,palette='deep')
# Out:
# <AxesSubplot:title={'center':'Tipi di cibo consumati nel Mondo'}, xlabel='consumption', ylabel='food_category'>

# %%
tips = sns.load_dataset("tips")
g = sns.jointplot(x="total_bill", y="tip", data=tips,
                  kind="reg", truncate=False,
                  xlim=(0, 60), ylim=(0, 12),
                  color="m", height=7)

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
fig, ax = plt.subplots(figsize = (14,7))
plt.title('Distribuzione Grassi Saturi nei Cibi nei Fast Food',fontsize=20)
plt.xticks(fontsize=14,rotation=45)
plt.yticks(fontsize=12,rotation=45)

sns.boxenplot(x="restaurant", y="sat_fat",
              color="b", data=fileFastFood,palette='deep')
# Out:
# <AxesSubplot:title={'center':'Distribuzione Grassi Saturi nei Cibi nei Fast Food'}, xlabel='restaurant', ylabel='sat_fat'>

# %%
# https://www.healthdata.org/us-health/data-download
# https://ourworldindata.org/obesity

# %%
fileObesita = pd.read_csv('IHME_county_data_LifeExpectancy_Obesity_PhysicalActivity_NATIONAL.csv',sep=';')
fileObesita
# Out:
#               State      County  Male obesity prevalence. 2001 (Perc)  \
# 0     United States         NaN                                  26.1
# 1           Alabama         NaN                                  29.7
# 2           Alabama     Autauga                                  30.7
# 3           Alabama     Baldwin                                  27.8
# 4           Alabama     Barbour                                  32.3
# ...             ...         ...                                   ...
# 3189        Wyoming  Sweetwater                                  26.6
# 3190        Wyoming       Teton                                  17.8
# 3191        Wyoming       Uinta                                  24.1
# 3192        Wyoming    Washakie                                  23.5
# 3193        Wyoming      Weston                                  27.0
#
#       Female obesity prevalence. 2001 (Perc)  \
# 0                                       28.7
# ...

# %%
fileObesita2 = pd.read_csv('number-of-deaths-by-risk-factor.csv')
fileObesita2
# Out:
#            Entity Code  Year  \
# 0     Afghanistan  AFG  1990
# 1     Afghanistan  AFG  1991
# 2     Afghanistan  AFG  1992
# 3     Afghanistan  AFG  1993
# 4     Afghanistan  AFG  1994
# ...           ...  ...   ...
# 6835     Zimbabwe  ZWE  2015
# 6836     Zimbabwe  ZWE  2016
# 6837     Zimbabwe  ZWE  2017
# 6838     Zimbabwe  ZWE  2018
# 6839     Zimbabwe  ZWE  2019
#
#       Deaths - Cause: All causes - Risk: Outdoor air pollution - OWID - Sex: Both - Age: All Ages (Number)  \
# 0                                                  3169
# 1                                                  3222
# 2                                                  3395
# 3                                                  3623
# 4                                                  3788
# ...                                                 ...
# 6835                                               2835
# 6836                                               2781
# ...

# %%
fileObesita2['Deaths - Cause: All causes - Risk: High body-mass index - Sex: Both - Age: All Ages (Number)']
# Out:
# 0       9518
# 1       9489
# 2       9528
# 3       9611
# 4       9675
#         ...
# 6835    5636
# 6836    5849
# 6837    6047
# 6838    6248
# 6839    6475
# Name: Deaths - Cause: All causes - Risk: High body-mass index - Sex: Both - Age: All Ages (Number), Length: 6840, dtype: int64

# %%
plt.figure(figsize=(14, 7))

#plt.grid()

app = fileObesita2[fileObesita2.Entity == 'United States' ]

y = app['Deaths - Cause: All causes - Risk: High body-mass index - Sex: Both - Age: All Ages (Number)']
x = fileObesita2['Year'].unique()

plt.scatter(x, y,color=colors[9])

z = np.polyfit(x, y, 5)
p = np.poly1d(z)

colors = sns.color_palette('deep')

plt.title('Numero di Decessi per Obesità negli Stati Uniti',fontsize=20)
plt.xticks(fontsize=14,rotation=45)
plt.yticks(fontsize=12,rotation=45)
#plt.bar(x,y,color=colors[1])
plt.plot(x, p(x),color=colors[3],linewidth=2,linestyle='--')

# %%
plt.figure(figsize=(14, 7))

#plt.grid()

app = fileObesita2[fileObesita2.Entity == 'Italy' ]

y = app['Deaths - Cause: All causes - Risk: High body-mass index - Sex: Both - Age: All Ages (Number)']
x = fileObesita2['Year'].unique()

plt.scatter(x, y,color=colors[9])

z = np.polyfit(x, y, 5)
p = np.poly1d(z)

colors = sns.color_palette('deep')

plt.title('Numero di Decessi per Obesità in Italia',fontsize=20)
plt.xticks(fontsize=14,rotation=45)
plt.yticks(fontsize=12,rotation=45)
#plt.bar(x,y,color=colors[1])
plt.plot(x, p(x),color=colors[3],linewidth=2,linestyle='--')

# %%
plt.figure(figsize=(14, 7))

#plt.grid()

app = fileObesita2[fileObesita2.Entity == 'Italy' ]

y = app['Deaths - Cause: All causes - Risk: High body-mass index - Sex: Both - Age: All Ages (Number)']
x = fileObesita2['Year'].unique()

plt.scatter(x, y,color=colors[9])

z = np.polyfit(x, y, 5)
p = np.poly1d(z)

colors = sns.color_palette('deep')

plt.title('Numero di Decessi per Obesità in Italia',fontsize=20)
plt.xticks(fontsize=14,rotation=45)
plt.yticks(fontsize=12,rotation=45)
#plt.bar(x,y,color=colors[1])
plt.ylim(0, 400000)
plt.plot(x, p(x),color=colors[3],linewidth=2,linestyle='--')

# %%
plt.figure(figsize=(14, 7))

#plt.grid()

app = fileObesita2[fileObesita2.Entity == 'United States' ]

y = app['Deaths - Cause: All causes - Risk: High body-mass index - Sex: Both - Age: All Ages (Number)']
x = fileObesita2['Year'].unique()

plt.scatter(x, y,color=colors[9])

z = np.polyfit(x, y, 5)
p = np.poly1d(z)

colors = sns.color_palette('deep')

plt.title('Numero di Decessi per Obesità negli Stati Uniti',fontsize=20)
plt.xticks(fontsize=14,rotation=45)
plt.yticks(fontsize=12,rotation=45)
#plt.bar(x,y,color=colors[1])
plt.ylim(0, 400000)
plt.plot(x, p(x),color=colors[3],linewidth=2,linestyle='--')

# %%
fig, ax = plt.subplots(figsize=(7, 7), subplot_kw=dict(aspect="equal"))

colors = sns.color_palette('deep')

data = recipe = fileFreqFastFood['Perc'].values

recipe = []
somma = sum(data)

for el in range(len(fileFreqFastFood['Frequency'].values)):
    concat = str(round(fileFreqFastFood['Perc'].values[el]/somma * 100,2)) + "% " + fileFreqFastFood['Frequency'].values[el]
    recipe.append(concat)

wedges, texts = ax.pie(data, wedgeprops=dict(width=0.5), startangle=-40,colors=colors)

bbox_props = dict(boxstyle="square,pad=0.3", fc="w", ec="k", lw=0.72)
kw = dict(arrowprops=dict(arrowstyle="-"),
          bbox=bbox_props, zorder=0, va="center")

for i, p in enumerate(wedges):
    ang = (p.theta2 - p.theta1)/2. + p.theta1
    y = np.sin(np.deg2rad(ang))
    x = np.cos(np.deg2rad(ang))
    horizontalalignment = {-1: "right", 1: "left"}[int(np.sign(x))]
    connectionstyle = "angle,angleA=0,angleB={}".format(ang)
    kw["arrowprops"].update({"connectionstyle": connectionstyle})
    ax.annotate(recipe[i], xy=(x, y), xytext=(1.35*np.sign(x), 1.4*y),
                horizontalalignment=horizontalalignment, **kw, fontsize=15)

##ax.set_title("Frequenza nei Fast Food")

plt.show()

# %%
# https://www.hellofresh.co.uk/grocery-delivery/which-country-eats-the-most-junk-food

# %%
fileFreqMese = pd.read_csv('FrequenzaMeseFastFood.csv',sep=';')
fileFreqMese
# Out:
#      Unnamed: 0     Country        State  Perc
# 0             1     Belfast           UK  7.45
# 1             2        Mons      Belgium  7.32
# 2             3  Birmingham           UK  6.69
# 3             4     Glasgow           UK  6.63
# 4             5   Newcastle           UK  6.55
# ..          ...         ...          ...   ...
# 100         101  Klagenfurt      Austria  1.68
# 101         102        Graz      Austria  1.60
# 102         103   Neuenburg  Switzerland  1.58
# 103         104     Bregenz      Austria  1.53
# 104         105   Solothurn  Switzerland  1.53
#
# [105 rows x 4 columns]

# %%
fileFreqMese.State.unique()
# Out:
# array(['UK', 'Belgium', 'Switzerland', 'Sweden', 'Denmark', 'France',
#        'Netherlands', 'Germany', 'Austria'], dtype=object)

# %%
fileNumeroFastFood = pd.read_csv('NumeroFastFood.csv',sep=';')
fileNumeroFastFood
# Out:
#     Code         Country   Count
# 0    ARG       Argentina  434.00
# 1    ATG         Antigua    5.00
# 2    ABW           Aruba   23.00
# 3    BHS     The Bahamas   33.00
# 4    BRB        Barbados   15.00
# ..   ...             ...     ...
# 145  UKR         Ukraine   83.00
# 146  GBR  United Kingdom    5.28
# 147  ARE             UAE  569.00
# 148  YEM           Yemen    1.00
# 149  ZMB          Zambia   12.00
#
# [150 rows x 3 columns]

# %%
# https://www.economicshelp.org/blog/160312/economics/highest-and-lowest-rates-of-obesity-in-the-world/

# %%
fileNumeroObesi = pd.read_csv('ObesityWorld.csv',sep=';')
fileNumeroObesi
# Out:
#      Rank           Country  Perc
# 0       1             Nauru  61.0
# 1       2      Cook Islands  55.9
# 2       3             Palau  55.3
# 3       4  Marshall Islands  52.9
# 4       5            Tuvalu  51.6
# ..    ...               ...   ...
# 187   188          Cambodia   3.9
# 188   189             India   3.9
# 189   190       Timor-Leste   3.8
# 190   191        Bangladesh   3.6
# 191   192           Vietnam   2.1
#
# [192 rows x 3 columns]

# %%
fig, ax = plt.subplots(figsize = (20,15))

colors = sns.color_palette('deep')

plt.title('Top 25 Paesi (Percentuale Obesi)',fontsize=20)
plt.xticks(fontsize=12,rotation=45)
plt.yticks(fontsize=14,rotation=45)

plt.xlim(0,65)

plt.barh(y=fileNumeroObesi.Country[:25], width=fileNumeroObesi[:25].Perc,color=[
    'grey','grey','grey','grey','grey','grey','grey','grey','grey','grey',colors[3]
    ,colors[3],colors[3],colors[3],colors[3],colors[3],colors[3],colors[3],colors[3]
    ,colors[3],colors[3],colors[3],colors[3],colors[3],colors[3],colors[3]
])
# Out:
# <BarContainer object of 25 artists>

# %%
fig, ax = plt.subplots(figsize = (20,15))

colors = sns.color_palette('deep')

plt.title('Last 25 Paesi (Percentuale Obesi)',fontsize=20)
plt.xticks(fontsize=12,rotation=45)
plt.yticks(fontsize=14,rotation=45)

plt.xlim(0,65)

plt.barh(y=fileNumeroObesi.Country[len(fileNumeroObesi.Country)-25:], width=fileNumeroObesi[len(fileNumeroObesi.Country)-25:].Perc,color=colors[8])
# Out:
# <BarContainer object of 25 artists>

# %%
fig, ax = plt.subplots(figsize = (20,15))

colors = sns.color_palette('deep')

ordered_df = fileNumeroFastFood.sort_values(by='Count')

plt.title('Top 25 Paesi (Numero Fast Fod)',fontsize=20)
plt.xticks(fontsize=12,rotation=45)
plt.yticks(fontsize=14,rotation=45)

plt.barh(y=ordered_df.Country[len(ordered_df.Country)-25:], width=ordered_df[len(ordered_df.Country)-25:].Count,color=colors[6])
# Out:
# <BarContainer object of 25 artists>

# %%
colors = sns.color_palette('deep')

# %%
dfMc = pd.DataFrame({
'group': fileFastFood.restaurant[fileFastFood.restaurant == 'Mcdonalds'].unique(),
'Calorie': log(fileFastFood.calories[fileFastFood.restaurant == 'Mcdonalds'].mean()),
'Calorie Grasse': log(fileFastFood.cal_fat[fileFastFood.restaurant == 'Mcdonalds'].mean()),
'Totale Grassi': log(fileFastFood.total_fat[fileFastFood.restaurant == 'Mcdonalds'].mean()),
'Grassi Saturi': log(fileFastFood.sat_fat[fileFastFood.restaurant == 'Mcdonalds'].mean()),
'Grassi Acidi': log(fileFastFood.trans_fat[fileFastFood.restaurant == 'Mcdonalds'].mean()),
'Colesterolo': log(fileFastFood.cholesterol[fileFastFood.restaurant == 'Mcdonalds'].mean()),
'Sodio': log(fileFastFood.sodium[fileFastFood.restaurant == 'Mcdonalds'].mean()),
'Carboidrati': log(fileFastFood.total_carb[fileFastFood.restaurant == 'Mcdonalds'].mean()),
'Fibre': log(fileFastFood.fiber[fileFastFood.restaurant == 'Mcdonalds'].mean()),
'Zuccheri': log(fileFastFood.sugar[fileFastFood.restaurant == 'Mcdonalds'].mean()),
'Proteine': log(fileFastFood.protein[fileFastFood.restaurant == 'Mcdonalds'].mean()),
'Vitamina A': log(fileFastFood.vit_a[fileFastFood.restaurant == 'Mcdonalds'].mean()),
'Vitamina C': log(fileFastFood.vit_c[fileFastFood.restaurant == 'Mcdonalds'].mean()),
'Calcio': log(fileFastFood.calcium[fileFastFood.restaurant == 'Mcdonalds'].mean()),
})

# %%
calories = [log(fileFastFood.calories[fileFastFood.restaurant == x].mean()) for x in fileFastFood['restaurant'].unique()]
fat_cal = [log(fileFastFood.cal_fat[fileFastFood.restaurant == x].mean()) for x in fileFastFood['restaurant'].unique()]
total_fat = [log(fileFastFood.total_fat[fileFastFood.restaurant == x].mean()) for x in fileFastFood['restaurant'].unique()]
trans_fat = [log(fileFastFood.trans_fat[fileFastFood.restaurant == x].mean()) for x in fileFastFood['restaurant'].unique()]
cholesterol = [log(fileFastFood.cholesterol[fileFastFood.restaurant == x].mean()) for x in fileFastFood['restaurant'].unique()]
sodium = [log(fileFastFood.sodium[fileFastFood.restaurant == x].mean()) for x in fileFastFood['restaurant'].unique()]
total_carb = [log(fileFastFood.total_carb[fileFastFood.restaurant == x].mean()) for x in fileFastFood['restaurant'].unique()]
sat_fat = [log(fileFastFood.sat_fat[fileFastFood.restaurant == x].mean()) for x in fileFastFood['restaurant'].unique()]
fiber = [log(fileFastFood.fiber[fileFastFood.restaurant == x].mean()) for x in fileFastFood['restaurant'].unique()]
sugar = [log(fileFastFood.sugar[fileFastFood.restaurant == x].mean()) for x in fileFastFood['restaurant'].unique()]
protein = [log(fileFastFood.protein[fileFastFood.restaurant == x].mean()) for x in fileFastFood['restaurant'].unique()]
vit_a = [log(fileFastFood.vit_a[fileFastFood.restaurant == x].mean()) for x in fileFastFood['restaurant'].unique()]
vit_c = [log(fileFastFood.vit_c[fileFastFood.restaurant == x].mean()) for x in fileFastFood['restaurant'].unique()]
calcium = [log(fileFastFood.calcium[fileFastFood.restaurant == x].mean()) for x in fileFastFood['restaurant'].unique()]

# %%
df1 = pd.DataFrame({
'group': ['Mcdonalds', 'Chick Fil-A', 'Sonic', 'Arbys'],
'Calorie': calories[:4],
'Calorie Grasse': fat_cal[:4],
'Grassi': total_fat[:4],
#'Grassi Acidi': trans_fat[:4],
'Colesterolo': cholesterol[:4],
'Sodio': sodium[:4],
'Carboidrati': total_carb[:4],
'Grassi Saturi': sat_fat[:4],
'Fibre': fiber[:4],
'Zuccheri': sugar[:4],
'Proteine': protein[:4],
'Vitamina A' : vit_a[:4],
'Vitamina C' :vit_c[:4],
'Calcio' :calcium[:4]
})

for index in df1.keys():
    df1[index] = df1[index].fillna(0)

# %%
def make_spider( row, title, color):

    # number of variable
    categories=list(df1)[1:]
    N = len(categories)

    # What will be the angle of each axis in the plot? (we divide the plot / number of variable)
    angles = [n / float(N) * 2 * pi for n in range(N)]
    angles += angles[:1]

    # Initialise the spider plot
    ax = plt.subplot(2,2,row+1, polar=True, )

    # If you want the first axis to be on top:
    ax.set_theta_offset(pi / 2)
    ax.set_theta_direction(-1)

    # Draw one axe per variable + add labels labels yet
    plt.xticks(angles[:-1], categories, color='black', size=8)

    # Draw ylabels
    ax.set_rlabel_position(0)
    plt.yticks([2,4,6,8], ["2","4","6","8"], color="grey", size=7)
    plt.ylim(0,10)

    # Ind1
    values=df1.loc[row].drop('group').values.flatten().tolist()
    values += values[:1]
    ax.plot(angles, values, color=color, linewidth=2, linestyle='solid')
    ax.fill(angles, values, color=color, alpha=0.4)

    # Add a title
    plt.title(title, size=11, color=color, y=1.1)

    
# initialize the figure
my_dpi=96
plt.figure(figsize=(1000/my_dpi, 1000/my_dpi), dpi=my_dpi)
plt.subplots_adjust(wspace=0.5)
 
# Create a color palette:
my_palette = sns.color_palette('deep')
 
# Loop to plot
for row in range(0, len(df1.index)):
    make_spider( row=row, title=df1['group'][row], color=my_palette[row])

# %%
df2 = pd.DataFrame({
'group': ['Burger King','Dairy Queen', 'Subway', 'Taco Bell'],
'Calorie': calories[4:8],
'Calorie Grasse': fat_cal[4:8],
'Grassi': total_fat[4:8],
#'Grassi Acidi': trans_fat[4:8],
'Colesterolo': cholesterol[4:8],
'Sodio': sodium[4:8],
'Carboidrati': total_carb[4:8],
'Grassi Saturi': sat_fat[4:8],
'Fibre': fiber[4:8],
'Zuccheri': sugar[4:8],
'Proteine': protein[4:8],
'Vitamina A' : vit_a[4:8],
'Vitamina C' :vit_c[4:8],
'Calcio' :calcium[4:8]
})

for index in df2.keys():
    df2[index] = df2[index].fillna(0)

# %%
def make_spider( row, title, color):

    # number of variable
    categories=list(df2)[1:]
    N = len(categories)

    # What will be the angle of each axis in the plot? (we divide the plot / number of variable)
    angles = [n / float(N) * 2 * pi for n in range(N)]
    angles += angles[:1]

    # Initialise the spider plot
    ax = plt.subplot(2,2,row+1, polar=True, )

    # If you want the first axis to be on top:
    ax.set_theta_offset(pi / 2)
    ax.set_theta_direction(-1)

    # Draw one axe per variable + add labels labels yet
    plt.xticks(angles[:-1], categories, color='black', size=8)

    # Draw ylabels
    ax.set_rlabel_position(0)
    plt.yticks([2,4,6,8], ["2","4","6","8"], color="grey", size=7)
    plt.ylim(0,10)

    # Ind1
    values=df2.loc[row].drop('group').values.flatten().tolist()
    values += values[:1]
    ax.plot(angles, values, color=color, linewidth=2, linestyle='solid')
    ax.fill(angles, values, color=color, alpha=0.4)

    # Add a title
    plt.title(title, size=11, color=color, y=1.1)

    
# initialize the figure
my_dpi=96
plt.figure(figsize=(1000/my_dpi, 1000/my_dpi), dpi=my_dpi)
plt.subplots_adjust(wspace=0.5)
 
# Create a color palette:
my_palette = sns.color_palette('deep')[4:]
 
# Loop to plot
for row in range(0, len(df2.index)):
    make_spider( row=row, title=df2['group'][row], color=my_palette[row])

# %%
fileNumeroFastFood.Country.unique()
# Out:
# array(['Argentina', 'Antigua', 'Aruba', 'The Bahamas', 'Barbados',
#        'Bolivia', 'Bonaire', 'Brazil', 'Canada', 'Chile', 'Colombia',
#        'Costa Rica', 'Cuba', 'Curacao', 'Dominica', 'Dominican Republic',
#        'Ecuador', 'El Salvador', 'French Guiana', 'Grand Cayman',
#        'Grenada', 'Guadeloupe', 'Guatemala', 'Guyana', 'Honduras',
#        'Jamaica', 'Martinique', 'Mexico', 'Nicaragua', 'Panama',
#        'Paraguay', 'Peru', 'Puerto Rico', 'St Kitts', 'St Lucia',
#        'St Maarten', 'St Vincent', 'Suriname', 'Trinidad & tobago',
#        'United States', 'Uruguay', 'US Virgin Islands', 'Venezuela',
#        'Afghanistan', 'American Samoa', 'Australia', 'Bangladesh',
#        'Brunei', 'Cambodia', 'China', 'Fiji', 'Guam', 'Hong Kong',
#        'India', 'Indonesia', 'Japan', 'Kazakhstan', 'Macau', 'Malaysia',
#        'Mongolia', 'Nepal', 'New Caledonia', 'New Zealand', 'Pakistan',
#        'Philippines', 'Reunion Island', 'Saipan', 'Singapore',
# ...
